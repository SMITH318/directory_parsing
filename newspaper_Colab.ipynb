# %%
# !cd /content/drive/MyDrive/newspaper_ocr/newspaper_utilities
# !ls
# Out:
# drive  jan11_exp  sample_data

# %%
# !ls
# Out:
# drive  jan11_exp  sample_data

# %%
! apt-get install poppler-utils
# !pip install pdf2image

# %%
! python scripts/01_preprocess.py
# Out:
# python3: can't open file '/content/scripts/01_preprocess.py': [Errno 2] No such file or directory

# %%
import pandas as pd

# %%
pd.read_json("/content/drive/MyDrive/newspaper_ocr/newspaper_utilities/data/02_raw/ocr_output.jsonl", lines=True)
# Out:
#               pub  page  col                                        text  \
# 0         Alabama     1    0                                     ALABAMA
# 1         Alabama     1    0                       ABANDA, 125, CHAMBERS
# 2         Alabama     1    0             CLARK, JAMES THOMAS (b'76)-Ala.
# 3         Alabama     1    0                               4,'11; (I'11)
# 4         Alabama     1    0           Turk, Wm. Pelham-Ga.5,'92; (I'01)
# ...           ...   ...  ...                                         ...
# 16009  California    15    2  Hagan, Ralph (b'72)-Cal.6,'95; (l'95); 758
# 16010  California    15    2   Lake St.; office, 424 S. Broadway; 11-12,
# 16011  California    15    2                                        3-5;
# 16012  California    15    2   Haigh, Frederic (b'68)-Ill.4,'93; (l'97);
# 16013  California    15    2                     Byrne Bldg.; 10:30-4:30
#
#        conf                                               bbox
# ...
